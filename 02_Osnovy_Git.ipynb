# %% [markdown]
# Задание 1, подтверждающее, что Jupyter установлен на локальной машине

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://pastenow.ru/BFTC0

# %% [markdown]
# Задание 2. Скрины из Learn Git Branching

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202021-01-31%20%D0%B2%2012.44.23.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202021-01-31%20%D0%B2%2012.44.23.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202021-01-31%20%D0%B2%2012.28.25.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202021-01-31%20%D0%B2%2012.28.25.png)

# %% [markdown]
# Задание 3. Ссылка на репозиторий с домашним заданием

# %%
https://github.com/dochaauch/Python_for_analisys
